# %% [markdown]
# <a href="https://colab.research.google.com/github/manash059/day-10/blob/main/day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.sample(5)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 1354 2019-03-12 05:50:18 2019-03-12 05:55:23           1      0.50   5.5
# 1237 2019-03-20 23:16:28 2019-03-20 23:22:24           1      0.98   6.0
# 2787 2019-03-20 20:07:29 2019-03-20 20:17:44           1      1.50   8.5
# 3965 2019-03-09 22:50:50 2019-03-09 23:00:46           1      1.23   7.5
# 6202 2019-03-31 09:43:27 2019-03-31 09:45:33           1      0.43   3.5
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 1354  0.00    0.0   9.30  yellow         cash           Clinton East
# 1237  0.00    0.0   9.80  yellow         cash  Upper East Side South
# 2787  0.00    0.0  12.30  yellow  credit card               Flatiron
# 3965  1.19    0.0  12.49  yellow  credit card       Garment District
# 6202  0.00    0.0   4.30   green         cash   Central Harlem North
#
#                        dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df['color'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.shape[0]
# Out:
# 6433

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
df.drop('pickup_zone',axis=1,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop(['pickup','color','payment','total'],axis=1,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
a=np.random.randint(10,50,15)

# %%
a
# Out:
# array([11, 20, 21, 12, 38, 17, 29, 47, 26, 24, 22, 42, 24, 15, 27])

# %%
a[a>20]
# Out:
# array([21, 38, 29, 47, 26, 24, 22, 42, 24, 27])

# %%
a[3]
# Out:
# 12

# %%
df[df['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 5446 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5447 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5448 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5449 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5450 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment                  dropoff_zone  \
# ...

# %%
df['payment']=='cash'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430     True
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool

# %%
df[df['payment']=='cash']
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.0
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 13   2019-03-19 07:55:25 2019-03-19 08:09:17           1      1.75  10.5  0.0
# 14   2019-03-27 12:13:34 2019-03-27 12:25:48           0      2.90  11.5  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6420 2019-03-16 15:39:23 2019-03-16 15:46:18           2      1.20   7.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0  0.0
#
# ...

# %%
df[(df['payment']=='cash') & (df['total']>15)]
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# 16   2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.0  0.0
# 26   2019-03-03 02:45:36 2019-03-03 03:02:14           1      3.35  13.5  0.0
# 29   2019-03-06 08:09:03 2019-03-06 08:27:11           1      0.92  12.0  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6407 2019-03-07 16:35:42 2019-03-07 16:50:03           1      2.68  12.0  0.0
# 6408 2019-03-04 07:27:58 2019-03-04 07:49:25           1      6.48  22.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0  0.0
#
# ...
